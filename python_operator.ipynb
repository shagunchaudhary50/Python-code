# %% [markdown]
# # Arithmetic operator

# %%
num1=15
num2=20
total=num1+num2
print(total)
# Out:
# 35

# %%
num1=50
num2=18
diff=num1-num2
print(diff)
# Out:
# 32

# %%
num1=9
num2=7
produt=num1*num2
print(produt)
# Out:
# 63

# %%
a=5000
b=2
remainder=5000%2
print("your remainder is",remainder)
# Out:
# your remainder is 0

# %%
a=12
a**=2
print(a)
# Out:
# 144

# %%
num = 5
num **=3
print(num)
# Out:
# 125

# %%
num = 29
num //=5
print(num)
# Out:
# 5

# %% [markdown]
# # Comparison operator

# %%
a=10
b=5
print(a>b)
# Out:
# True

# %%
a=15
b=25
print(a<b)
# Out:
# True

# %%
a=20
b=20
print(a==b)
# Out:
# True

# %%
a=30
b=10
print(a!=b)
# Out:
# True

# %%
a=45
b=40
print(a>=b)
# Out:
# True

# %%
a=3
b=8
print(a<=b)
# Out:
# True

# %% [markdown]
# # Logical operator

# %%
num1=2
num2=2 
num3=4
print(num1==num2 and num2==num3)
# Out:
# False

# %%
num1=2
num2=2 
num3=4
print(num1==num2 or num2==num3)
# Out:
# True

# %%
num1=2
num2=2 
num3=4
print(num1==num2 or num2==num3)
print(not True)
# Out:
# True
# False

# %%
print(not False)
# Out:
# True

# %% [markdown]
# # Assignment operator

# %%
x=10
x=x+5
print(x)
# Out:
# 15

# %%
x=10
x+=5
print(x)
# Out:
# 15

# %%
x=20
x-=4
print(x)
# Out:
# 16

# %%
x=6
x*=3
print(x)
# Out:
# 18

# %%
x=40
x/=2
print(x)
# Out:
# 20.0

# %%
x=5
x**=2
print(x)
# Out:
# 25

# %%
x=20
x%=3
print(x)
# Out:
# 2

# %% [markdown]
# # Identify operator

# %%
a=10
b=10
print(a is b)
# Out:
# True

# %%
a=[1,2,3]
b=[1,2,3]
print(a is b)
# Out:
# False

# %%
a=10
b=12
print(a is not b)
print(id(a))
print(id(b))
# Out:
# True
# 140705943364808
# 140705943364872

# %% [markdown]
# # Membership operator

# %%
string="apple"
print("a" in string)
# Out:
# True

# %%
string="python"
print("x" in string)
# Out:
# False

# %%
a=[1,2,3,4,5]
print(3 in a)
# Out:
# True

# %% [markdown]
# # Bitwise operator

# %%
25 & 12
# Out:
# 8

# %%
bin(25)
# Out:
# '0b11001'

# %%
25|12
# Out:
# 29
